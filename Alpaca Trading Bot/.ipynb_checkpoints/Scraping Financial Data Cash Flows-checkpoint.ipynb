# %% [markdown]
# # What We Can Do
#
# We can get 4 year of financial data cleanly outputted
#
# Link: https://towardsdatascience.com/web-scraping-for-accounting-analysis-using-python-part-1-b5fc016a1c9a
#
#
# Goal is to be able to quickly analyze data to narrowdown investment opportunities

# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as ur

# %%
# Enter a stock symbol
index= "FB"
# URL link 
url_is = "https://finance.yahoo.com/quote/" + index + "/financials?p=" + index
url_bs = "https://finance.yahoo.com/quote/" + index +"/balance-sheet?p=" + index
url_cf = "https://finance.yahoo.com/quote/" + index + "/cash-flow?p="+ index

# %%
read_data = ur.urlopen(url_bs).read() 
soup_is= BeautifulSoup(read_data,"lxml")

# %%
ls= [] # Create empty list
for l in soup_is.find_all("div"): 
  #Find all data structure that is ‘div’
  ls.append(l.string) # add each element one by one to the list
 
ls = [e for e in ls if e not in ("Operating Expenses","Non-recurring Events")] # Exclude those columns

# %%
new_ls = list(filter(None,ls))

# %%
new_ls = new_ls[12:]

# %%
is_data = list(zip(*[iter(new_ls)]*6))

# %%
Income_st = pd.DataFrame(is_data[0:])

# %%
Income_st.columns = Income_st.iloc[0] # Name columns to first row of dataframe
Income_st = Income_st.iloc[1:,] # start to read 1st row
Income_st = Income_st.T # transpose dataframe
Income_st.columns = Income_st.iloc[0] #Name columns to first row of dataframe
Income_st.drop(Income_st.index[0],inplace=True) #Drop first index row
Income_st.index.name = "" # Remove the index name
Income_st.rename(index={"ttm": "12/31/2019"},inplace=True) #Rename ttm in index columns to end of the year
Income_st = Income_st[Income_st.columns[:-5]] # remove last 5 irrelevant columns

# %%
Income_st
# Out:
# Quarterly                                    19,079,000  31,095,000  \
#
# 12/31/2019                                   10,019,000  33,632,000
# 12/31/2018                                    8,079,000  20,546,000
# 12/31/2017                                    8,903,000  Total Cash
# 12/31/2016                 Other Short Term Investments  54,855,000
# Cash And Cash Equivalents                    35,776,000  41,114,000
#
# Quarterly                       41,711,000             3,993,000  \
#
# 12/31/2019                      29,449,000  Total Current Assets
# 12/31/2018                 Net Receivables            66,225,000
# 12/31/2017                       9,518,000            50,480,000
# 12/31/2016                       7,587,000            48,563,000
# Cash And Cash Equivalents        5,832,000            34,401,000
#
# Quarterly                 Gross property, plant and equipment  \
#
# 12/31/2019                                         55,446,000
# 12/31/2018                                         31,573,000
# 12/31/2017                                         18,337,000
# 12/31/2016                                         11,803,000
# Cash And Cash Equivalents            Accumulated Depreciation
#
# Quarterly                                        -10,663,000  24,683,000  \
#
# 12/31/2019                                        -6,890,000  13,721,000
# 12/31/2018                                        -4,616,000   8,591,000
# 12/31/2017                                        -3,212,000    Goodwill
# 12/31/2016                 Net property, plant and equipment  18,715,000
# Cash And Cash Equivalents                         44,783,000  18,301,000
#
# Quarterly                         18,221,000               2,535,000  \
#
# 12/31/2019                        18,122,000  Other long-term assets
# 12/31/2018                 Intangible Assets               2,759,000
# 12/31/2017                           894,000               2,576,000
# 12/31/2016                         1,294,000               2,135,000
# Cash And Cash Equivalents          1,884,000               1,312,000
#
# Quarterly                 Total non-current assets   133,376,000  \
#
# 12/31/2019                              67,151,000    97,334,000
# 12/31/2018                              46,854,000    84,524,000
# 12/31/2017                              35,961,000    64,961,000
# 12/31/2016                              30,560,000  Current Debt
# Cash And Cash Equivalents             Total Assets       277,000
#
# Quarterly                           500,000              380,000  \
#
# 12/31/2019                                -              302,000
# 12/31/2018                                -  Accrued liabilities
# 12/31/2017                 Accounts Payable            6,632,000
# 12/31/2016                        1,363,000            1,531,000
# Cash And Cash Equivalents           820,000              685,000
#
# Quarterly                            331,000  Other Current Liabilities  \
#
# 12/31/2019                 Deferred revenues                  2,498,000
# 12/31/2018                           269,000                  1,784,000
# 12/31/2017                           147,000                  1,201,000
# 12/31/2016                            98,000                  1,236,000
# Cash And Cash Equivalents             90,000  Total Current Liabilities
#
# Quarterly                                  15,053,000  \
#
# 12/31/2019                                  7,017,000
# 12/31/2018                                  3,760,000
# 12/31/2017                                  2,875,000
# 12/31/2016                 Deferred taxes liabilities
# Cash And Cash Equivalents                   1,039,000
#
# Quarterly                                      673,000  \
#
# 12/31/2019                                           -
# 12/31/2018                                           -
# 12/31/2017                 Other long-term liabilities
# 12/31/2016                                   1,055,000
# Cash And Cash Equivalents                      862,000
#
# Quarterly                                      1,045,000
#
# 12/31/2019                                       461,000
# 12/31/2018                 Total non-current liabilities
# 12/31/2017                                    17,269,000
# 12/31/2016                                     6,190,000
# Cash And Cash Equivalents                      6,417,000

# %%
finalIS = Income_st[1:5]

# %%
finalIS
# Out:
# Quarterly                                    19,079,000  31,095,000  \
#
# 12/31/2018                                    8,079,000  20,546,000
# 12/31/2017                                    8,903,000  Total Cash
# 12/31/2016                 Other Short Term Investments  54,855,000
# Cash And Cash Equivalents                    35,776,000  41,114,000
#
# Quarterly                       41,711,000   3,993,000  \
#
# 12/31/2018                 Net Receivables  66,225,000
# 12/31/2017                       9,518,000  50,480,000
# 12/31/2016                       7,587,000  48,563,000
# Cash And Cash Equivalents        5,832,000  34,401,000
#
# Quarterly                 Gross property, plant and equipment  \
#
# 12/31/2018                                         31,573,000
# 12/31/2017                                         18,337,000
# 12/31/2016                                         11,803,000
# Cash And Cash Equivalents            Accumulated Depreciation
#
# Quarterly                                        -10,663,000  24,683,000  \
#
# 12/31/2018                                        -4,616,000   8,591,000
# 12/31/2017                                        -3,212,000    Goodwill
# 12/31/2016                 Net property, plant and equipment  18,715,000
# Cash And Cash Equivalents                         44,783,000  18,301,000
#
# Quarterly                         18,221,000  2,535,000  \
#
# 12/31/2018                 Intangible Assets  2,759,000
# 12/31/2017                           894,000  2,576,000
# 12/31/2016                         1,294,000  2,135,000
# Cash And Cash Equivalents          1,884,000  1,312,000
#
# Quarterly                 Total non-current assets   133,376,000  \
#
# 12/31/2018                              46,854,000    84,524,000
# 12/31/2017                              35,961,000    64,961,000
# 12/31/2016                              30,560,000  Current Debt
# Cash And Cash Equivalents             Total Assets       277,000
#
# Quarterly                           500,000              380,000  331,000  \
#
# 12/31/2018                                -  Accrued liabilities  269,000
# 12/31/2017                 Accounts Payable            6,632,000  147,000
# 12/31/2016                        1,363,000            1,531,000   98,000
# Cash And Cash Equivalents           820,000              685,000   90,000
#
# Quarterly                  Other Current Liabilities  \
#
# 12/31/2018                                 1,784,000
# 12/31/2017                                 1,201,000
# 12/31/2016                                 1,236,000
# Cash And Cash Equivalents  Total Current Liabilities
#
# Quarterly                                  15,053,000  \
#
# 12/31/2018                                  3,760,000
# 12/31/2017                                  2,875,000
# 12/31/2016                 Deferred taxes liabilities
# Cash And Cash Equivalents                   1,039,000
#
# Quarterly                                      673,000  \
#
# 12/31/2018                                           -
# 12/31/2017                 Other long-term liabilities
# 12/31/2016                                   1,055,000
# Cash And Cash Equivalents                      862,000
#
# Quarterly                                      1,045,000
#
# 12/31/2018                 Total non-current liabilities
# 12/31/2017                                    17,269,000
# 12/31/2016                                     6,190,000
# Cash And Cash Equivalents                      6,417,000

# %% [markdown]
# ## Financial Statement Analysis
# Income Statement: Look for increasing operating income, % of revenue increase
#
# Statement of Cash Flow: We need to be able to automatically change into the summary analysis and make judgments
#
# Balance Sheet: Just look at key accounts, and calculate that ratio you did in Grubhub Project (Z-ratio)

# %%
isAnalysis = finalIS

# %%
# Use iloc in this particular analysis, or loc if you can for the specific names

isAnalysis.iloc[0:3, 0:4]
# Out:
# Quarterly                     19,079,000  31,095,000       41,711,000  \
#
# 12/31/2018                     8,079,000  20,546,000  Net Receivables
# 12/31/2017                     8,903,000  Total Cash        9,518,000
# 12/31/2016  Other Short Term Investments  54,855,000        7,587,000
#
# Quarterly    3,993,000
#
# 12/31/2018  66,225,000
# 12/31/2017  50,480,000
# 12/31/2016  48,563,000
