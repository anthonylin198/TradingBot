# %% [markdown]
# # What We can Do
#
# We can get 4 year of financial data cleanly outputted
#
# Link: https://towardsdatascience.com/web-scraping-for-accounting-analysis-using-python-part-1-b5fc016a1c9a

# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as ur

# %%
# Enter a stock symbol
index= "MSFT"
# URL link 
url_is = "https://finance.yahoo.com/quote/" + index + "/financials?p=" + index
url_bs = "https://finance.yahoo.com/quote/" + index +"/balance-sheet?p=" + index
url_cf = "https://finance.yahoo.com/quote/" + index + "/cash-flow?p="+ index

# %%
read_data = ur.urlopen(url_is).read() 
soup_is= BeautifulSoup(read_data,"lxml")

# %%
ls= [] # Create empty list
for l in soup_is.find_all("div"): 
  #Find all data structure that is ‘div’
  ls.append(l.string) # add each element one by one to the list
 
ls = [e for e in ls if e not in ("Operating Expenses","Non-recurring Events")] # Exclude those columns

# %%
new_ls = list(filter(None,ls))

# %%
new_ls = new_ls[12:]

# %%
is_data = list(zip(*[iter(new_ls)]*6))

# %%
Income_st = pd.DataFrame(is_data[0:])

# %%
Income_st.columns = Income_st.iloc[0] # Name columns to first row of dataframe
Income_st = Income_st.iloc[1:,] # start to read 1st row
Income_st = Income_st.T # transpose dataframe
Income_st.columns = Income_st.iloc[0] #Name columns to first row of dataframe
Income_st.drop(Income_st.index[0],inplace=True) #Drop first index row
Income_st.index.name = "" # Remove the index name
Income_st.rename(index={"ttm": "12/31/2019"},inplace=True) #Rename ttm in index columns to end of the year
Income_st = Income_st[Income_st.columns[:-5]] # remove last 5 irrelevant columns

# %%
Income_st
# Out:
# Annual                                 11,356,000  121,822,000  \
#
# 6/29/2019                              11,946,000  125,318,000
# 6/29/2018                               7,663,000  106,730,000
# 6/29/2017                               6,510,000   Total Cash
# 6/29/2016                  Short Term Investments  133,819,000
# Cash And Cash Equivalents             122,463,000  133,768,000
#
# Annual                         132,981,000 18,277,000  Other Current Assets  \
#
# 6/29/2019                      113,240,000  Inventory            10,146,000
# 6/29/2018                  Net Receivables  2,063,000             6,751,000
# 6/29/2017                       29,524,000  2,662,000             4,897,000
# 6/29/2016                       26,481,000  2,181,000             5,892,000
# Cash And Cash Equivalents       19,792,000  2,251,000  Total Current Assets
#
# Annual                                             175,552,000  \
#
# 6/29/2019                                          169,662,000
# 6/29/2018                                          159,851,000
# 6/29/2017                                          139,660,000
# 6/29/2016                  Gross property, plant and equipment
# Cash And Cash Equivalents                           79,186,000
#
# Annual                                   65,369,000  \
#
# 6/29/2019                                47,913,000
# 6/29/2018                                38,156,000
# 6/29/2017                  Accumulated Depreciation
# 6/29/2016                               -35,330,000
# Cash And Cash Equivalents               -29,223,000
#
# Annual                                           -24,179,000  \
#
# 6/29/2019                                        -19,800,000
# 6/29/2018                  Net property, plant and equipment
# 6/29/2017                                         43,856,000
# 6/29/2016                                         36,146,000
# Cash And Cash Equivalents                         23,734,000
#
# Annual                                       18,356,000           Goodwill  \
#
# 6/29/2019                  Equity and other investments         42,026,000
# 6/29/2018                                     2,649,000         35,683,000
# 6/29/2017                                     1,862,000         35,122,000
# 6/29/2016                                     6,023,000         17,872,000
# Cash And Cash Equivalents                    10,431,000  Intangible Assets
#
# Annual                     ...    81,235,000   193,694,000 Accounts Payable  \
#                            ...
# 6/29/2019                  ...    54,034,000  Current Debt        9,382,000
# 6/29/2018                  ...  Total Assets     5,516,000        8,617,000
# 6/29/2017                  ...   286,556,000     3,998,000        7,390,000
# 6/29/2016                  ...   258,848,000    10,121,000        6,898,000
# Cash And Cash Equivalents  ...   241,086,000    12,904,000    Taxes payable
#
# Annual                             5,665,000                 28,905,000  \
#
# 6/29/2019                          2,121,000                 34,102,000
# 6/29/2018                            718,000                 27,468,000
# 6/29/2017                            580,000  Other Current Liabilities
# 6/29/2016                  Deferred revenues                  9,351,000
# Cash And Cash Equivalents         32,676,000                  8,744,000
#
# Annual                                     6,280,000      59,357,000  \
#
# 6/29/2019                                  5,949,000  Long Term Debt
# 6/29/2018                  Total Current Liabilities      66,662,000
# 6/29/2017                                 69,420,000      72,242,000
# 6/29/2016                                 58,488,000      76,073,000
# Cash And Cash Equivalents                 64,527,000      40,783,000
#
# Annual                    Deferred taxes liabilities  \
#
# 6/29/2019                                    233,000
# 6/29/2018                                    541,000
# 6/29/2017                                    531,000
# 6/29/2016                                  1,476,000
# Cash And Cash Equivalents          Deferred revenues
#
# Annual                                       4,530,000  \
#
# 6/29/2019                                    3,815,000
# 6/29/2018                                   10,377,000
# 6/29/2017                                    6,441,000
# 6/29/2016                  Other long-term liabilities
# Cash And Cash Equivalents                    7,581,000
#
# Annual                                         5,211,000
#
# 6/29/2019                                     17,184,000
# 6/29/2018                                     13,640,000
# 6/29/2017                  Total non-current liabilities
# 6/29/2016                                    114,806,000
# Cash And Cash Equivalents                    117,642,000
#
# [5 rows x 22 columns]

# %%
finalIS = Income_st[1:5]

# %%
finalIS
# Out:
# Annual                                 11,356,000  121,822,000  \
#
# 6/29/2018                               7,663,000  106,730,000
# 6/29/2017                               6,510,000   Total Cash
# 6/29/2016                  Short Term Investments  133,819,000
# Cash And Cash Equivalents             122,463,000  133,768,000
#
# Annual                         132,981,000 18,277,000  Other Current Assets  \
#
# 6/29/2018                  Net Receivables  2,063,000             6,751,000
# 6/29/2017                       29,524,000  2,662,000             4,897,000
# 6/29/2016                       26,481,000  2,181,000             5,892,000
# Cash And Cash Equivalents       19,792,000  2,251,000  Total Current Assets
#
# Annual                                             175,552,000  \
#
# 6/29/2018                                          159,851,000
# 6/29/2017                                          139,660,000
# 6/29/2016                  Gross property, plant and equipment
# Cash And Cash Equivalents                           79,186,000
#
# Annual                                   65,369,000  \
#
# 6/29/2018                                38,156,000
# 6/29/2017                  Accumulated Depreciation
# 6/29/2016                               -35,330,000
# Cash And Cash Equivalents               -29,223,000
#
# Annual                                           -24,179,000  18,356,000  \
#
# 6/29/2018                  Net property, plant and equipment   2,649,000
# 6/29/2017                                         43,856,000   1,862,000
# 6/29/2016                                         36,146,000   6,023,000
# Cash And Cash Equivalents                         23,734,000  10,431,000
#
# Annual                              Goodwill  ...    81,235,000 193,694,000  \
#                                               ...
# 6/29/2018                         35,683,000  ...  Total Assets   5,516,000
# 6/29/2017                         35,122,000  ...   286,556,000   3,998,000
# 6/29/2016                         17,872,000  ...   258,848,000  10,121,000
# Cash And Cash Equivalents  Intangible Assets  ...   241,086,000  12,904,000
#
# Annual                    Accounts Payable          5,665,000  \
#
# 6/29/2018                        8,617,000            718,000
# 6/29/2017                        7,390,000            580,000
# 6/29/2016                        6,898,000  Deferred revenues
# Cash And Cash Equivalents    Taxes payable         32,676,000
#
# Annual                                    28,905,000  \
#
# 6/29/2018                                 27,468,000
# 6/29/2017                  Other Current Liabilities
# 6/29/2016                                  9,351,000
# Cash And Cash Equivalents                  8,744,000
#
# Annual                                     6,280,000  59,357,000  \
#
# 6/29/2018                  Total Current Liabilities  66,662,000
# 6/29/2017                                 69,420,000  72,242,000
# 6/29/2016                                 58,488,000  76,073,000
# Cash And Cash Equivalents                 64,527,000  40,783,000
#
# Annual                    Deferred taxes liabilities  \
#
# 6/29/2018                                    541,000
# 6/29/2017                                    531,000
# 6/29/2016                                  1,476,000
# Cash And Cash Equivalents          Deferred revenues
#
# Annual                                       4,530,000  \
#
# 6/29/2018                                   10,377,000
# 6/29/2017                                    6,441,000
# 6/29/2016                  Other long-term liabilities
# Cash And Cash Equivalents                    7,581,000
#
# Annual                                         5,211,000
#
# 6/29/2018                                     13,640,000
# 6/29/2017                  Total non-current liabilities
# 6/29/2016                                    114,806,000
# Cash And Cash Equivalents                    117,642,000
#
# [4 rows x 22 columns]
